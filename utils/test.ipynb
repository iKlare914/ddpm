# %%
import torch as th
from torch import nn
import numpy as np

# %%
arr = th.tensor(np.array([1, 2]), dtype=th.float32)
np_arr = np.array([1, 2], dtype=np.float32)
batch = th.tensor(np.ones((2, 3, 3, 3)), dtype=th.float32)
# Out:
# torch.Size([2, 1, 1])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 batch = th.tensor(np.ones((2, 3, 3, 3)), dtype=th.float32)
#       4
#       5 print(arr.unsqueeze(-1).unsqueeze(-1).shape)
#       6
# ----> 7 arr.unsqueeze(-1).unsqueeze(-1).unsqueeze() * batch
#
# TypeError: unsqueeze() missing 1 required positional arguments: "dim"

# %%
array = th.tensor(th.arange(0, 10), dtype=th.float32) - 1
np_array = np.arange(0, 10, dtype=np.float32)
print(len(np_array.shape))
print(len(array.shape) == 1)
print(array)
# Out:
# 1
# True
# tensor([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.])
# /tmp/ipykernel_16474/486651235.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   array = th.tensor(th.arange(0, 10), dtype=th.float32) - 1

# %%
spaced_arr = th.arange(0, 10, 7, dtype=th.float32)
print(spaced_arr)
# Out:
# tensor([0., 7.])
